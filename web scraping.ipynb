# %%
#Q1
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://en.wikipedia.org/wiki/Main_Page"
response = requests.get(url)
 
soup = BeautifulSoup(response.content)

header_tags = soup.find_all(["h1", "h2", "h3", "h4", "h5", "h6"])

header_texts = [tag.get_text() for tag in header_tags]

df = pd.DataFrame(header_texts, columns=["Header"])

df
# Out:
#                            Header
# 0                       Main Page
# 1            Welcome to Wikipedia
# 2   From today's featured article
# 3                Did you know ...
# 4                     In the news
# 5                     On this day
# 6      From today's featured list
# 7        Today's featured picture
# 8        Other areas of Wikipedia
# 9     Wikipedia's sister projects
# 10            Wikipedia languages

# %%
#Q3
#Top 10 teams
url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
response = requests.get(url)
soup = BeautifulSoup(response.content)

team_data = []
table = soup.find("table", class_="table")
rows = table.find_all("tr")

for row in rows[1:11]:
  cells = row.find_all("td")
  team = cells[1].text.strip()
  matches = cells[2].text.strip()
  points = cells[3].text.strip()
  rating = cells[4].text.strip()
  team_data.append({"Team":team,"Matches":matches,"Points":points,"Rating":rating})
    
df=pd.DataFrame(team_data)
df
# Out:
#                Team Matches Points Rating
# 0        India\nIND      55  6,640    121
# 1    Australia\nAUS      42  4,926    117
# 2  South Africa\nSA      34  3,750    110
# 3     Pakistan\nPAK      36  3,922    109
# 4   New Zealand\nNZ      43  4,399    102
# 5      England\nENG      38  3,777     99
# 6     Sri Lanka\nSL      47  4,134     88
# 7   Bangladesh\nBAN      44  3,836     87
# 8  Afghanistan\nAFG      30  2,533     84
# 9   West Indies\nWI      38  2,582     68

# %%
#Top 10 batsmen

url="https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"
response=requests.get(url)
soup=BeautifulSoup(response.content)

batsmen_data=[]
table=soup.find("table",class_="table rankings-table")
rows = table.find_all("tr")

for row in rows[1:11]:
  cells = row.find_all("td")
  batsmen = cells[1].text.strip()
  team=cells[2].text.strip()
  rating = cells[3].text.strip()
  batsmen_data.append({"Team":team,"Batsmen":batsmen,"Rating":rating})
    
df=pd.DataFrame(batsmen_data)
df
# Out:
#   Team                Batsmen Rating
# 0  IND           Shubman Gill    826
# 1  PAK             Babar Azam    824
# 2  IND            Virat Kohli    791
# 3  IND           Rohit Sharma    769
# 4   SA        Quinton de Kock    760
# 5   NZ         Daryl Mitchell    750
# 6  AUS           David Warner    745
# 7   SA  Rassie van der Dussen    735
# 8  IRE           Harry Tector    729
# 9  ENG            Dawid Malan    729

# %%
#Top10 Blowers

url="https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling"
response=requests.get(url)
soup=BeautifulSoup(response.content)

bowlers_data=[]
table=soup.find("table",class_="table rankings-table")
rows = table.find_all("tr")

for row in rows[1:11]:
  cells = row.find_all("td")
  bowlers = cells[1].text.strip()
  team=cells[2].text.strip()
  rating = cells[3].text.strip()
  bowlers_data.append({"Team":team,"Bowlers":bowlers,"Rating":rating})
    
df=pd.DataFrame(bowlers_data)
df
# Out:
#   Team         Bowlers Rating
# 0   SA  Keshav Maharaj    741
# 1  AUS  Josh Hazlewood    703
# 2  IND  Mohammed Siraj    699
# 3  IND  Jasprit Bumrah    685
# 4  AUS      Adam Zampa    675
# 5  AFG     Rashid Khan    667
# 6  IND   Kuldeep Yadav    667
# 7   NZ     Trent Boult    663
# 8  PAK  Shaheen Afridi    650
# 9  IND  Mohammad Shami    648

# %%
#Q4
url="https://www.icc-cricket.com/rankings/womens/team-rankings/odi"
response=requests.get(url)
soup=BeautifulSoup(response.content)

womens_team=[]
table=soup.find("table",class_="table")
rows=table.find_all("tr")

for row in rows[1:11]:
    cells=row.find_all("td")
    team=cells[1].text.strip()
    matches=cells[2].text.strip()
    point=cells[3].text.strip()
    rating=cells[4].text.strip()
    womens_team.append({"Team":team,"Matches":matches,"Point":point,"Rating":rating})

df=pd.DataFrame(womens_team)
df
# Out:
#                Team Matches  Point Rating
# 0    Australia\nAUS      21  3,429    163
# 1      England\nENG      23  2,991    130
# 2  South Africa\nSA      21  2,446    116
# 3        India\nIND      18  1,745     97
# 4   New Zealand\nNZ      21  2,014     96
# 5   West Indies\nWI      20  1,768     88
# 6     Sri Lanka\nSL       9    714     79
# 7   Bangladesh\nBAN      14  1,074     77
# 8     Thailand\nTHA      11    753     68
# 9     Pakistan\nPAK      24  1,602     67

# %%
url="https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting"
response=requests.get(url)
soup=BeautifulSoup(response.content)

batting_data=[]
table = soup.find("table", class_="table rankings-table")
rows  = table.find_all("tr")

for row in rows[1:11]:
    cells = row.find_all("td")
    player = cells[1].text.strip()
    team = cells[2].text.strip()
    rating = cells[3].text.strip()
    batting_data.append({"Player":player,"Team":team,"Rating":rating})
    
df=pd.DataFrame(batting_data)
print("####TOP 10 Batswomen####")
df
# Out:
# ####TOP 10 Batswomen####
#                  Player Team Rating
# 0  Natalie Sciver-Brunt  ENG    807
# 1           Beth Mooney  AUS    750
# 2   Chamari Athapaththu   SL    736
# 3       Laura Wolvaardt   SA    727
# 4       Smriti Mandhana  IND    708
# 5          Alyssa Healy  AUS    698
# 6          Ellyse Perry  AUS    697
# 7      Harmanpreet Kaur  IND    694
# 8           Meg Lanning  AUS    662
# 9        Marizanne Kapp   SA    642

# %%
url="https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder"
response=requests.get(url)
soup=BeautifulSoup(response.content)

allrounder_data=[]
table = soup.find("table", class_="table rankings-table")
rows  = table.find_all("tr")

for row in rows[1:11]:
    cells = row.find_all("td")
    all_rounder = cells[1].text.strip()
    team = cells[2].text.strip()
    rating = cells[3].text.strip()
    allrounder_data.append({"All_Rounder":all_rounder,"Team":team,"Rating":rating})
    
df=pd.DataFrame(allrounder_data)
print('#####Top 10 all-rounders#####')
df
# Out:
# #####Top 10 all-rounders#####
#             All_Rounder Team Rating
# 0        Marizanne Kapp   SA    385
# 1      Ashleigh Gardner  AUS    377
# 2  Natalie Sciver-Brunt  ENG    360
# 3       Hayley Matthews   WI    358
# 4           Amelia Kerr   NZ    346
# 5         Deepti Sharma  IND    312
# 6          Ellyse Perry  AUS    282
# 7              Nida Dar  PAK    240
# 8         Jess Jonassen  AUS    227
# 9         Sophie Devine   NZ    227

# %%
#Q5
url = "https://www.cnbc.com/world/?region=world"
response = requests.get(url)
soup = BeautifulSoup(response.content)
articles = soup.find_all("div", class_="Card-titleContainer")

headlines = []
times = []
links = []

for article in articles:
  headline = article.find("a").text.strip()
  headlines.append(headline)
  link = article.find("a")["href"]
  links.append(link)

df=pd.DataFrame({"Headline":headlines,"Link":links})
df
# Out:
#                                              Headline  \
# 0   Stocks making the biggest moves midday: Tesla,...
# 1   Dow jumps 200 points, building on 2023 gains a...
# 2   Fed Chair Powell calls talk of cutting rates '...
# 3   Treasury yields fall even as Powell says rate-...
# 4   Bill Gates warns the world is likely to smash ...
# 5   UAE commits $30 billion to new climate-focused...
# 6   Progress on sustainability in the fashion indu...
# 7   Estonian PM calls on global powers to emulate ...
# 8   Bill Gates shares his ‘big hope’ for the COP28...
# 9   Op-ed: With continued geopolitical conflicts, ...
# 10  Zelenskyy says 'new phase of war' has begun, H...
# 11  Multiple civilians injured in strikes on Ukrai...
# 12  Russia slams Finland's border closure, warns t...
# 13  Finland to close entire border with Russia; wi...
# 14               CNBC's Sustainable Future Forum 2023
# 15  Wind power industry in moment of reckoning as ...
# ...

# %%
url = "https://www.journals.elsevier.com/artificial-intelligence/most-downloaded-articles"
response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")
articles_container = soup.find("div",class_="sc-orwwe2-3 jOMrrY")

titles = []
authors = []
dates = []
urls = []

for article in articles_container.find_all("li"):
  title = article.find("h2")
  titles.append(title)
  
  author = article.find("span", class_="sc-1w3fpd7-0 dnCnAO")
  authors.append(author)

  date = article.find("span",class_="sc-1thf9ly-2 dvggWt")
  dates.append(date)
  
  link = article.find("a")["href"]
  urls.append(link)

data = {
  "Paper Title": titles,
  "Authors": authors,
  "Published Date": dates,
  "Paper URL": urls
}
df = pd.DataFrame(data)

(df)
# Out:
#                                           Paper Title  \
# 0                                  [Reward is enough]
# 1   [Explanation in artificial intelligence: Insig...
# 2            [Creativity and artificial intelligence]
# 3   [Conflict-based search for optimal multi-agent...
# 4   [Knowledge graphs as tools for explainable mac...
# 5   [Law and logic: A review from an argumentation...
# 6   [Between MDPs and semi-MDPs: A framework for t...
# 7   [Explaining individual predictions when featur...
# 8     [Multiple object tracking: A literature review]
# 9   [A survey of inverse reinforcement learning: C...
# 10  [Evaluating XAI: A comparison of rule-based an...
# 11  [Explainable AI tools for legal reasoning abou...
# 12          [Hard choices in artificial intelligence]
# 13  [Assessing the communication gap between AI mo...
# 14  [Explaining black-box classifiers using post-h...
# 15  [The Hanabi challenge: A new frontier for AI r...
# ...

# %%
#Q7
url = "https://www.dineout.co.in/delhi-restaurants/buffet-special"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

restaurant_names = soup.find_all("div",class_="restnt-info cursor")
cuisines = soup.find_all('div', class_='restnt-loc ellipsis')
locations = soup.find_all('div', class_='restnt-loc ellipsis')
ratings = soup.find_all('div', class_="restnt-rating rating-4")
image_urls = soup.find_all('img',class_="no-img")

restaurant_list = []
cuisine_list = []
location_list = []
rating_list = []
image_url_list = []

for name in restaurant_names:
  restaurant_list.append(name.text.strip())

for cuisine in cuisines:
  cuisine_list.append(cuisine.text.strip())

for location in locations:
  location_list.append(location.text.strip())

for rating in ratings:
  rating_list.append(rating.text.strip())

for image in image_urls:
  image_url_list.append(image['data-src'])

data = {
  'Restaurant Name': restaurant_list,
  'Cuisine': cuisine_list,
  'Location': location_list,
  'Ratings': rating_list,
  'Image URL': image_url_list
}
df=pd.DataFrame(data)
df
# Out:
#                                      Restaurant Name  \
# 0      Castle BarbequeConnaught Place, Central Delhi
# 1  Cafe KnoshThe Leela Ambience Convention Hotel,...
# 2    India GrillHilton Garden Inn,Saket, South Delhi
# 3  The Barbeque CompanyGardens Galleria,Sector 38...
# 4  Delhi BarbequeTaurus Sarovar Portico,Mahipalpu...
# 5  The Monarch - Bar Be Que VillageIndirapuram Ha...
# 6  The Barbeque TimesM2K Corporate Park,Sector 51...
#
#                                              Cuisine  \
# 0                     Connaught Place, Central Delhi
# 1  The Leela Ambience Convention Hotel,Shahdara, ...
# 2               Hilton Garden Inn,Saket, South Delhi
# 3                 Gardens Galleria,Sector 38A, Noida
# 4     Taurus Sarovar Portico,Mahipalpur, South Delhi
# 5  Indirapuram Habitat Centre,Indirapuram, Ghaziabad
# 6              M2K Corporate Park,Sector 51, Gurgaon
#
#                                             Location Ratings  \
# ...
