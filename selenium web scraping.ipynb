# %%
# !pip install selenium

# %%
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time

# %%
#Question1
driver=webdriver.Chrome()

# %%
driver.get("https://www.shine.com/")

# %%
skill=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[1]/div/input")
skill.send_keys("Data Analyst")

# %%
place=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
place.send_keys("Bangalore")

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button")
search.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience=[]

# %%
title_tags=driver.find_elements(By.XPATH ,'//h2[@itemprop="name"]/a[1]')
for i in title_tags[:11]:
    title_tags=i.text
    job_title.append(title_tags)

# %%
location=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location[:11]:
    location=i.text
    job_location.append(location)

# %%
name=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]/span')
for i in name[:11]:
    name=i.text
    company_name.append(name)

# %%
experience_tag=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience_tag[:11]:
    experience_tag=i.text
    experience.append(experience_tag)

# %%
df=pd.DataFrame({"Title":job_title,"Location":job_location,"Company":company_name,"Experience":experience})

# %%
df
# Out:
#                                            Title        Location  \
# 0                         Marketing Data Analyst   Bangalore\n+1
# 1                       Data Analyst Recruitment  Bangalore\n+13
# 2                                   Data Analyst   Bangalore\n+9
# 3                       Vacancy For Data Analyst  Bangalore\n+13
# 4   Project Coordinator (Data Analyst) Bangalore       Bangalore
# 5   Project Coordinator (Data analyst) Bangalore       Bangalore
# 6   Business Data Analyst - Modeling & Profiling       Bangalore
# 7                   Data analyst - Java / Python       Bangalore
# 8                     Data Analyst - Java/Python       Bangalore
# 9       Data Analyst - SQL/ Database Maintenance       Bangalore
# 10  Business Data Analyst - Modeling & Profiling       Bangalore
#
#                                    Company   Experience
# 0                              novel group   2 to 6 Yrs
# 1                        kavya interprises   0 to 4 Yrs
# ...

# %%
###Question2

# %%
driver=webdriver.Chrome()

# %%
driver.get("http://www.shine.com/")

# %%
designation=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[1]/div/input")
designation.send_keys('data scientist')

# %%
location=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[2]/div/input")
location.send_keys('Bangalore')

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button")
search.click()

# %%
Job_title1=[]
Job_location1=[]
Company_name1=[]

# %%
title=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]/a[1]')
for i in title[:10]:
    title=i.text
    Job_title1.append(title)

# %%
location1=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in location1[:10]:
    location1=i.text
    Job_location1.append(location1)

# %%
name1=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]/span')
for i in name1[:10]:
    name1=i.text
    Company_name1.append(name1)

# %%
sf=pd.DataFrame({"Title":Job_title1,"Location":Job_location1,"Company":Company_name1})

# %%
sf
# Out:
#                                     Title        Location  \
# 0                          Data scientist   Bangalore\n+8
# 1  Data Scientist - Business Intelligence       Bangalore
# 2            Data Scientist for Bangalore       Bangalore
# 3  Data Scientist - Spark/Python/Redshift       Bangalore
# 4       Data Scientist - Machine Learning       Bangalore
# 5               Hiring For Data Scientist  Bangalore\n+13
# 6               Hiring For Data Scientist  Bangalore\n+13
# 7                          Data Scientist       Bangalore
# 8               Data Scientist- Associate       Bangalore
# 9                  Data Scientist Vacancy  Bangalore\n+14
#
#                                   Company
# 0  capgemini technology services india...
# 1  boyen haddin consulting and technol...
# 2                               get hired
# 3  boyen haddin consulting and technol...
# 4  boyen haddin consulting and technol...
# 5                       kavya interprises
# ...

# %%
####Question3

# %%
driver=webdriver.Chrome()

# %%
driver.get(" https://www.shine.com/")

# %%
skills=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[1]/ul/li[1]/div/input")
skills.send_keys("Data Scientist")

# %%
search=driver.find_element(By.XPATH,"/html/body/div/div[4]/div/div[2]/div[2]/div/form/div/div[2]/div/button")
search.click()

# %%
filters=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[3]/div/div[1]/div/div[2]/div/ul/li[3]/button")
filters.click()

# %%
select=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[3]/div/div[1]/div/div[2]/div[2]/div/div/div/div[3]/div/div/div/ul/li[3]/span/label")
select.click()

# %%
show_result=driver.find_element(By.XPATH,"/html/body/div[1]/div[1]/div[3]/div/div[1]/div/div[2]/div[2]/div/div/div/div[4]/button[2]")
show_result.click()

# %%
job_title2=[]
job_location2=[]
company_name2=[]
experience_required2=[]

# %%
title=driver.find_elements(By.XPATH,'//h2[@itemprop="name"]/a[1]')
for i in title[:10]:
    title=i.text
    job_title2.append(title)

# %%
place=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_locationIcon__zrWt2"]')
for i in place[:10]:
    place=i.text
    job_location2.append(place)

# %%
name=driver.find_elements(By.XPATH,'//div[@class="jobCard_jobCard_cName__mYnow"]/span')
for i in name[:10]:
    name=i.text
    company_name2.append(name)

# %%
experience=driver.find_elements(By.XPATH,'//div[@class=" jobCard_jobCard_lists_item__YxRkV jobCard_jobIcon__3FB1t"]')
for i in experience[:10]:
    experience=i.text
    experience_required2.append(experience)

# %%
yf=pd.DataFrame({"Title":job_title2,"Location":job_location2,"Company":company_name2,"Experience":experience_required2})

# %%
yf
# Out:
#                                     Title           Location  \
# 0             Data Scientist (ML/AI) Pune               Pune
# 1  Data Scientist - Business Intelligence          Bangalore
# 2                Data Scientist - Kolkata            Kolkata
# 3            Data Scientist - West Bengal  Other West Bengal
# 4                 Data Scientist - Odisha       Other Odisha
# 5                 Data Scientist - Punjab       Other Punjab
# 6                Data Scientist - Haryana      Other Haryana
# 7               Data Scientist - Bathinda           Bathinda
# 8                 Data Scientist - Jaipur             Jaipur
# 9                   Data Scientist - Kota               Kota
#
#                                   Company  Experience
# 0         gfl recruitment private limited   0 to 1 Yr
# 1  boyen haddin consulting and technol...  2 to 6 Yrs
# 2                               get hired  0 to 3 Yrs
# 3                               get hired  0 to 3 Yrs
# ...

# %%
####Question4

# %%
driver=webdriver.Chrome()

# %%
from selenium.webdriver.common.keys import Keys

# %%
driver.get('https://www.flipkart.com/')

# %%
Cut_loginpage=driver.find_element(By.XPATH,'/html/body/div[3]/div/span')
Cut_loginpage.click()

# %%
sunglass=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
sunglass.send_keys("Sunglasses")

# %%
enter=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
enter.send_keys(Keys.ENTER)

# %%
#this page only having 40 sunglasses

# %%
Brand=[]
Product_Description=[]
Price=[]
Discount=[]

# %%
brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand[:36]:
    brand=i.text
    Brand.append(brand)

# %%
description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description[:36]:
    description=i.text
    Product_Description.append(description)

# %%
price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price[:36]:
    price=i.text
    Price.append(price)

# %%
discount=driver.find_elements(By.XPATH,'//div[@class="_3I9_wc"]')
for i in discount[:36]:
    discount=i.text
    Discount.append(discount)

# %%
next_page=driver.find_element(By.XPATH,'/html/body/div/div/div[3]/div[1]/div[2]/div[12]/div/div/nav/a[11]')
next_page.click()

# %%
brand=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand[:36]:
    brand=i.text
    Brand.append(brand)

# %%
description=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description[:36]:
    description=i.text
    Product_Description.append(description)

# %%
price=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price[:36]:
    price=i.text
    Price.append(price)

# %%
discount=driver.find_elements(By.XPATH,'//div[@class="_3I9_wc"]')
for i in discount[:36]:
    discount=i.text
    Discount.append(discount)

# %%
data=pd.DataFrame({"Brand_name":Brand,"Description":Product_Description,"Rate":Price,"Discount":Discount})

# %%
data
# Out:
#    Brand_name                                        Description  Rate  \
# 0        SRPM             UV Protection Wayfarer Sunglasses (50)  ₹149
# 1    Fastrack             UV Protection Wayfarer Sunglasses (58)  ₹549
# 2    Fastrack   UV Protection Rectangular Sunglasses (Free Size)  ₹449
# 3        SRPM             UV Protection Wayfarer Sunglasses (50)  ₹169
# 4   ALFATOORE    UV Protection, Mirrored Aviator Sunglasses (58)  ₹449
# ..        ...                                                ...   ...
# 67   Fastrack  Polarized, UV Protection Rectangular Sunglasse...  ₹629
# 68  Rich Club  UV Protection, Riding Glasses Rectangular Sung...  ₹199
# 69     Hooper         UV Protection Round Sunglasses (Free Size)  ₹539
# 70    PC STAR  Riding Glasses, UV Protection Clubmaster, Wayf...  ₹149
# 71   PROVOGUE  Polarized, UV Protection Retro Square Sunglass...  ₹599
#
#    Discount
# 0    ₹1,299
# 1    ₹1,099
# 2      ₹899
# 3    ₹1,299
# 4    ₹1,499
# ..      ...
# 67   ₹1,099
# ...

# %%
###Question5

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.flipkart.com/apple-iphone-11-black-64-gb/product-reviews/itm4e5041ba101fd?pid=MOBFWQ6BXGJCEYNY&lid=LSTMOBFWQ6BXGJCEYNYHWAXCG&marketplace=FLIPKART')

# %%
Rating=[]
Summary=[]
full_review=[]

# %%
    rating=driver.find_elements(By.XPATH,'//div[@class="_3LWZlK _1BLPMq"]')
    for i in rating:
        Rating.append(i.text)
    summary=driver.find_elements(By.XPATH,'//p[@class="_2-N8zT"]')  
    for i in summary:
        Summary.append(i.text)
    review=driver.find_elements(By.XPATH,'//div[@class="t-ZTKy"]/div')    
    for i in review:
        full_review.append(i.text)

# %%
data2=pd.DataFrame({"Rating":Rating,"Summary":Summary,"Review":full_review})

# %%
data2
# Out:
#   Rating              Summary  \
# 0      5       Classy product
# 1      5     Perfect product!
# 2      5    Worth every penny
# 3      5            Brilliant
# 4      5  Best in the market!
# 5      5             Terrific
# 6      5            Wonderful
# 7      5    Terrific purchase
# 8      5    Terrific purchase
# 9      5            Fabulous!
#
#                                               Review
# 0  Camera is awesome\nBest battery backup\nA perf...
# 1                                       Photos super
# 2  Feeling awesome after getting the delivery of ...
# 3                           very good camera quality
# 4                                        Good Camera
# 5                                     Very very good
# 6                             This is amazing at all
# 7                                  Value for money 😍
# 8                                 Value for money 🖤🖤
# 9                    Super🔥 and good performance 👌❤️

# %%
###Question6

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.flipkart.com/")

# %%
sneaker=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
sneaker.send_keys("Sneakers")

# %%
enter=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
enter.send_keys(Keys.ENTER)

# %%
Brand2=[]
Description2=[]
Price2=[]

# %%
brand1=driver.find_elements(By.XPATH,'//div[@class="_2WkVRV"]')
for i in brand1[:35]:
    brand1=i.text
    Brand2.append(brand1)

# %%
description1=driver.find_elements(By.XPATH,'//a[@class="IRpwTa"]')
for i in description1[:35]:
    description1=i.text
    Description2.append(description1)

# %%
price1=driver.find_elements(By.XPATH,'//div[@class="_30jeq3"]')
for i in price1[:35]:
    price1=i.text
    Price2.append(price1)

# %%
data3=pd.DataFrame({"Brand":Brand2,"Description":Description2,"Price":Price2})

# %%
data3
# Out:
#            Brand                                        Description   Price
# 0         Footox                  Sneakers For Men Sneakers For Men    ₹399
# 1         BRUTON      Combo Pack Of 2 Casual Shoes Sneakers For Men    ₹479
# 2      Deals4you                                 Sneakers For Women    ₹399
# 3       URBANBOX  Trending Stylish Casual Outdoor Sneakers Shoes...    ₹299
# 4         CAMPUS                           ANNIE Sneakers For Women    ₹989
# 5           aadi                                   Sneakers For Men    ₹319
# 6           aadi  Lightweight,Comfort,Summer,Trendy,Walking,Outd...    ₹329
# 7           aadi  Mesh |Lightweight|Comfort|Summer|Trendy|Walkin...    ₹299
# 8   Kook N Keech                                 Sneakers For Women    ₹594
# 9       Vellinto            Casual Sneakrs For Men Sneakers For Men    ₹555
# 10          aadi  Lightweight,Comfort,Summer,Trendy,Walking,Outd...    ₹356
# ...

# %%
###Question7

# %%
driver=webdriver.Chrome()

# %%
driver.get(' https://www.amazon.in/')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
search.send_keys('Laptop')

# %%
click=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
click.click()

# %%
filters=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[2]/div/div[3]/span/div[1]/div/div/div[6]/ul[7]/span[10]/li/span/a/span')
filters.click()

# %%
title2=[]
rating2=[]
price2=[]

# %%
title=driver.find_elements(By.XPATH,'//span[@class="a-size-medium a-color-base a-text-normal"]')
for i in title[:10]:
    title2.append(i.text)
rating=driver.find_elements(By.XPATH,'//span[@class="a-icon-alt"]')    
for i in rating[:10]:
    rating2.append(i.text)
price=driver.find_elements(By.XPATH,'//span[@class="a-price-whole"]')
for i in price[:10]:
    price2.append(i.text)

# %%
data4=pd.DataFrame({"Title":title2,"Rating":rating2,"Price":price2})

# %%
data4
# Out:
#                                                Title Rating     Price
# 0  ASUS Vivobook 16 (2023), Intel Core i9-13900H ...           79,990
# 1  ASUS Vivobook 14X OLED, Intel Core i9-13900H 1...         1,09,990
# 2  Dell G15-5520 Gaming Laptop, Intel Core i9-129...         1,18,990
# 3  Acer Predator Helios Neo 16 Gaming Laptop 13th...         1,54,990
# 4  Acer Predator Helios 16 Gaming Laptop 13th Gen...         1,69,990
# 5  MSI Titan GT77 HX, Intel 13th Gen. i9-13980HX,...         5,69,990
# 6  MSI Stealth 16 Mercedes-AMG, Intel 13th Gen. i...         2,82,087
# 7  ASUS Creator Series Vivobook Pro 16 OLED 2023,...         1,54,990
# 8  HP OMEN Transcend Laptop 13th Gen Intel® Core™...         2,39,299
# 9  (Refurbished) ASUS Vivobook S 15 OLED (2023), ...           89,241

# %%
##question8

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.azquotes.com/")

# %%
click=driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div/div[3]/ul/li[5]/a')
click.click()

# %%
Quote=[]
Author=[]
Type_of_quote=[]

# %%
quote=driver.find_elements(By.XPATH,'//a[@class="title"]')
for i in quote:
    Quote.append(i.text)
author=driver.find_elements(By.XPATH,'//div[@class="author"]')
for i in author:
    Author.append(i.text)
typeofquote=driver.find_elements(By.XPATH,'//div[@class="tags"]')  
for i in typeofquote:
    Type_of_quote.append(i.text)

# %%
data5=pd.DataFrame({"Quote":Quote,"Author":Author,"Type of Quote":Type_of_quote})

# %%
data5
# Out:
#                                                 Quote                Author  \
# 0   The essence of strategy is choosing what not t...        Michael Porter
# 1   One cannot and must not try to erase the past ...            Golda Meir
# 2   Patriotism means to stand by the country. It d...    Theodore Roosevelt
# 3   Death is something inevitable. When a man has ...        Nelson Mandela
# 4   You have to love a nation that celebrates its ...          Erma Bombeck
# ..                                                ...                   ...
# 95     When the going gets weird, the weird turn pro.    Hunter S. Thompson
# 96  When a train goes through a tunnel and it gets...       Corrie Ten Boom
# 97  If you think you are too small to make a diffe...            Dalai Lama
# 98  God doesn't require us to succeed, he only req...         Mother Teresa
# 99    Change your thoughts and you change your world.  Norman Vincent Peale
#
#                                Type of Quote
# ...

# %%
###question9

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.jagranjosh.com/')

# %%
gk=driver.find_element(By.XPATH,'/html/body/div/header/nav/div/div/div[3]/ul/li[7]/a')
gf.click()

# %%
prime_minister=driver.find_element(By.XPATH,'/html/body/div[1]/div[8]/section[17]/div/div/ul[2]/li[11]/a')
prime_minister.click()

# %%
Name=[]
Born_And_Dead=[]
Term_of_Office=[]
Remarks=[]

# %%
#sorry sir i tried my best but i can't get follwing xpath is there no attributes for there xpath really confusing,please explain
this questiom

# %%
##Question10

# %%
driver=webdriver.Chrome()

# %%
driver.get(' https://www.motor1.com/')

# %%
cars=driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/input')
cars.send_keys("50 most expensive cars")

# %%
search=driver.find_element(By.XPATH,'/html/body/div[10]/div[2]/div/div/div[3]/div/div/div/form/button[1]')
search.click()

# %%
click=driver.find_element(By.XPATH,'/html/body/div[10]/div[9]/div/div[1]/div/div/div[2]/div/div[1]/h3/a')
click.click()

# %%
Cars_Name=[]
Car_Price=[]

# %%
Cars=driver.find_elements(By.XPATH,'//h3[@class="subheader"]')
for i in Cars[:50]:
    Cars_Name.append(i.text)
car_price=driver.find_elements(By.XPATH,'//p/strong')
for i in car_price[:50]:
    Car_Price.append(i.text)

# %%
data6=pd.DataFrame({"Cars_Name":Cars_Name,"Cars_Price":Car_Price})

# %%
data6
# Out:
#                              Cars_Name                   Cars_Price
# 0                  Aston Martin Valour          Price: $1.5 Million
# 1                         McLaren Elva          Price: $1.7 Million
# 2                          Czinger 21C          Price: $1.7 Million
# 3                        Ferrari Monza          Price: $1.7 Million
# 4                   Gordon Murray T.33          Price: $1.7 Million
# 5                    Koenigsegg Gemera          Price: $1.7 Million
# 6                          Zenvo TSR-S          Price: $1.7 Million
# 7                   Hennessey Venom F5          Price: $1.8 Million
# 8                      Bentley Bacalar          Price: $1.9 Million
# 9        Hispano Suiza Carmen Boulogne          Price: $1.9 Million
# 10              Bentley Mulliner Batur          Price: $2.0 Million
# 11                        Deus Vayanne          Price: $2.0 Million
# 12                         SSC Tuatara          Price: $2.0 Million
# ...
